# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("mnist_custom.h5")

# %%
# import the MNIST dataset
(x_train_mnist, y_train_mnist), (x_test_mnist, y_test_mnist) = tf.keras.datasets.mnist.load_data()
x_train_mnist = x_train_mnist.reshape(60000, 28, 28, 1)
x_test_mnist = x_test_mnist.reshape(10000, 28, 28, 1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
model.evaluate(x_test_mnist, y_test_mnist)
# Out:
# 313/313 [==============================] - 7s 21ms/step - loss: 0.0686 - accuracy: 0.9812
# [0.06860414147377014, 0.9811999797821045]
